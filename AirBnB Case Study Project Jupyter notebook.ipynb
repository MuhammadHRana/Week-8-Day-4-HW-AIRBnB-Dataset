# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# Your task will be to take the data provided and find evidence to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
# This is to simulate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('./AB_NYC_2019.csv')
air_bnb.head()

# %%
# How many neighborhood groups are available and which shows up the most?

print(air_bnb['neighbourhood_group'].unique())
len(air_bnb['neighbourhood_group'].unique())
print(air_bnb.groupby('neighbourhood_group')['id'].nunique())
max(air_bnb.groupby('neighbourhood_group')['id'].nunique())


#Answer: 5 total, Manhattan is the most common at 21661 times.

# print(air_bnb.neighbourhood_group.nunique())

# increment=0
# boroughs = {}

# for idx,i in enumerate(air_bnb['neighbourhood_group'].unique()):
#     boroughs[idx] = i

# boroughs
# while increment < len(air_bnb['neighbourhood_group'].unique()):
#     for borough in air_bnb['neighbourhood_group'].unique():
#         air_bnb['neighbourhood_group'][air_bnb[f'{borough}']].sum()
#         increment += 1




# air_bnb['neighbourhood_group'][air_bnb['neighbourhood_group'].unique()[0]]

# max = air_bnb.iloc[air_bnb.groupby(['neighbourhood_group']).apply(lambda x: x.idxmax())]
# max

# %%
# Are private rooms the most popular in manhattan?

print(air_bnb['room_type'].unique())
len(air_bnb['room_type'].unique())
print(air_bnb.groupby('room_type')['id'].nunique())
max(air_bnb.groupby('room_type')['id'].nunique())

#Answer: No, Entire home/apt are the most popular.

# %%
# Which hosts are the busiest and based on their reviews?


df_new = air_bnb[["host_id","reviews_per_month"]].dropna()

df_new = df_new.groupby('reviews_per_month')

max(df_new)

#Answer is host_id #42075 with reviews_per_month of 58.5

# %%
#Which neighorhood group has the highest average price?

df_average = air_bnb[["neighbourhood_group","price"]]

df_new = air_bnb["neighbourhood_group"].unique()


df_average_price = (df_average.groupby("neighbourhood_group").price.apply(lambda g: g.sum()))
df_newer = df_average[0:0]

for idx, i in enumerate(df_average_price):
    df_newer.loc[idx] = [df_new[idx], i]

for idx, i in enumerate(df_average.groupby("neighbourhood_group").size()):
    df_newer.loc[idx, "Count"] = i
    df_newer.loc[idx, "Highest_Average"] = df_newer.loc[idx, "price"] / df_newer.loc[idx, "Count"]


df_newer.head()
# max(df_newer["Highest_Average"])

# Answer: Queens has the highest average price

# %%
# Which neighbor hood group has the highest total price?

#Answer see above, Queens

# %%
#Which top 5 hosts have the highest total price?

df_newer_total = air_bnb[["host_name","price"]]


# df_average = air_bnb[["neighbourhood_group","price"]]

# df_new = air_bnb["neighbourhood_group"].unique()

df_new_total = air_bnb["host_name"].unique()


# df_average_price = (df_average.groupby("neighbourhood_group").price.apply(lambda g: g.sum()))
# df_newer = df_average[0:0]

df_newer_total_price = (df_newer_total.groupby("host_name").price.apply(lambda g: g.sum()))
df_newest = df_newer_total[0:0]

# for idx, i in enumerate(df_average_price):
#     df_newer.loc[idx] = [df_new[idx], i]

for idx, i in enumerate(df_newer_total_price):
    df_newest.loc[idx] = [df_new_total[idx], i]

# for idx, i in enumerate(df_average.groupby("neighbourhood_group").size()):
#     df_newer.loc[idx, "Count"] = i
#     df_newer.loc[idx, "Highest_Average"] = df_newer.loc[idx, "price"] / df_newer.loc[idx, "Count"]+

for idx, i in enumerate(df_newer_total.groupby("host_name").size()):
    df_newest.loc[idx, "Count"] = i
    df_newest.loc[idx, "Highest_Average"] = df_newest.loc[idx, "price"] / df_newest.loc[idx, "Count"]


df_newest = df_newest.groupby("Highest_Average")

# %%
air_bnb
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# Who currently has no (zero) availability with a review count of 100 or more?
df_avail = air_bnb[["host_name", "number_of_reviews", "availability_365"]]
answer = {}

for idx,i in df_avail["host_name"].iteritems():
    if df_avail["availability_365"][idx] == 0 and df_avail['number_of_reviews'][idx] >= 100:
        answer[i] = f'Number of reviews are: {df_avail["number_of_reviews"][idx]}. '

answer
# Out:
# {'MaryEllen': 'Number of reviews are: 118. ',
#  'Christiana': 'Number of reviews are: 168. ',
#  'Sol': 'Number of reviews are: 193. ',
#  'Coral': 'Number of reviews are: 114. ',
#  'Doug': 'Number of reviews are: 206. ',
#  'Ori': 'Number of reviews are: 205. ',
#  'Lissette': 'Number of reviews are: 147. ',
#  'Liz And Melissa': 'Number of reviews are: 131. ',
#  'Ivy': 'Number of reviews are: 115. ',
#  'Jsun': 'Number of reviews are: 205. ',
#  'Wanda': 'Number of reviews are: 480. ',
#  'Ben': 'Number of reviews are: 125. ',
#  'S': 'Number of reviews are: 233. ',
#  'Adrienne': 'Number of reviews are: 143. ',
#  'Lydia': 'Number of reviews are: 107. ',
#  'Karin': 'Number of reviews are: 101. ',
#  'Elle': 'Number of reviews are: 157. ',
#  'James': 'Number of reviews are: 320. ',
#  'Jon': 'Number of reviews are: 116. ',
#  'Liz': 'Number of reviews are: 128. ',
#  'Jeanine': 'Number of reviews are: 109. ',
#  'Lorena': 'Number of reviews are: 178. ',
# ...

# %%
# What host has the highest total of prices and where are they located?


df_newer_total = air_bnb[["host_name", "price", "neighbourhood"]]

df_new_total = air_bnb["host_name"].unique()


df_newer_total_price = (df_newer_total.groupby("neighbourhood").price.apply(lambda g: g.sum()))
df_newest = df_newer_total[0:0]
df_newer_total_price

neighbours = {}
prices = {}
iterations = 0

for idx, i in df_newer_total_price.iteritems():
    neighbours[iterations] = idx
    prices[iterations] = i
    iterations += 1

    


for idx, i in enumerate(df_newer_total_price):
    df_newest = df_newest.append({
        'host_name': df_new_total[idx],
        'price': prices[idx],
        'neighbourhood': neighbours[idx]},
        ignore_index = True
    )

checker = 0
winnner = {}
for idx, i in enumerate(df_newest['price']):
    if i > checker:
        checker = i
        winner = {
            'Name': df_newest["host_name"][idx],
            'Price': checker,
            'Neighbourhood': df_newest["neighbourhood"][idx]
        }

winner

# Answer is {'Name': 'Kristian & Di', 'Price': 563707, 'Neighbourhood': 'Williamsburg'}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17324/1127417272.py in <module>
#      24
#      25 for idx, i in enumerate(df_newer_total_price):
# ---> 26     df_newest = df_newest.pd.concat({
#      27         'host_name': df_new_total[idx],
#      28         'price': prices[idx],
#
# ~\.conda\envs\january\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5581         ):
#    5582             return self[name]
# -> 5583         return object.__getattribute__(self, name)
#    5584
#    5585     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'pd'

# %%
# Out:
# 563707

# %%
# When did Danielle from Queens last receive a review?
import re

danielle = air_bnb[["host_name", "last_review"]]

# danielle= danielle[pd.to_numeric(danielle['last_review'], errors='coerce').notnull()]



danielle = danielle.dropna()
# danielle = danielle['host_name'].drop_duplicates

checker = 0
indexer = 0
from datetime import datetime
import _strptime as strptime

# danielle['last_review'] = pd.to_datetime(danielle['last_review'])
# danielle['last_review'].dtypes
date = dict()

for idx, i in enumerate(danielle['last_review']):
    date[idx] = i

for idx, i in enumerate(danielle["host_name"]):
    if i == "Danielle":
        if int(date[idx][0:4]) > checker:
            checker = date[idx][0:4]
            indexer = idx

print(f'Danielles latest login was {date[indexer]}')

# print(Column_A)
# date
# danielle
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17324/1222565287.py in <module>
#      25 for idx, i in enumerate(danielle["host_name"]):
#      26     if i == "Danielle":
# ---> 27         if int(date[idx][0:4]) > checker:
#      28             checker = date[idx][0:4]
#      29             indexer = idx
#
# TypeError: '>' not supported between instances of 'int' and 'str'

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %%
# Out:
# '2019-06-172019-06-17'

# %% [markdown]
# 2. How many listings have completely open availability?

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --
